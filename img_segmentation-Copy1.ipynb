# %%
# Common
import tensorflow as tf
from glob import glob
import numpy as np

# Data
from sklearn.model_selection import train_test_split
import cv2

# Data visualization
import matplotlib.pyplot as plt

# Model
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from keras.optimizers import Adam
from tensorflow.keras.utils import plot_model

# Metrics
from tensorflow.keras.metrics import *

# %%
paths = glob('archive/Dataset_BUSI_with_GT/*/*')

print(f'\033[92m')
print(f"'normal' class has {len([i for i in paths if 'normal' in i and 'mask' not in i])} images and {len([i for i in paths if 'normal' in i and 'mask' in i])} masks.")
print(f"'benign' class has {len([i for i in paths if 'benign' in i and 'mask' not in i])} images and {len([i for i in paths if 'benign' in i and 'mask' in i])} masks.")
print(f"'malignant' class has {len([i for i in paths if 'malignant' in i and 'mask' not in i])} images and {len([i for i in paths if 'malignant' in i and 'mask' in i])} masks.")
print(f"\nThere are total of {len([i for i in paths if 'mask' not in i])} images and {len([i for i in paths if 'mask' in i])} masks.")
# Out:
# 'normal' class has 133 images and 133 masks.
# 'benign' class has 437 images and 454 masks.
# 'malignant' class has 210 images and 211 masks.
#
# There are total of 780 images and 798 masks.

# %%
sorted(glob('archive/Dataset_BUSI_with_GT/*/*'))[4:7]
# Out:
# ['archive/Dataset_BUSI_with_GT\\benign\\benign (100).png',
#  'archive/Dataset_BUSI_with_GT\\benign\\benign (100)_mask.png',
#  'archive/Dataset_BUSI_with_GT\\benign\\benign (100)_mask_1.png']

# %%
def load_image(path, size):
    image = cv2.imread(path)
    image = cv2.resize(image, (size,size))
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)   # shape: (size,size,3) -> (size,size,1)
    image = image/255.   # normalize
    return image

def load_data(root_path, size):
    images = []
    masks = []
    
    x = 0   # additional variable to identify images consisting of 2 or more masks
    
    for path in sorted(glob(root_path)):
        img = load_image(path, size)   # read mask or image
            
        if 'mask' in path:
            if x:   # this image has masks more than one
                masks[-1] += img   # add the mask to the last mask
                    
                # When 2 masks are added, the range can increase by 0-2. So we will reduce it again to the range 0-1.
                masks[-1] = np.array(masks[-1]>0.5, dtype='float64')
            else:
                masks.append(img)
                x = 1   # if the image has a mask again, the above code will run next time
        else:
            images.append(img)
            x = 0   # for moving to the next image
    return np.array(images), np.array(masks)

# %%
size = 128   # image size: 128x128
X, y = load_data('archive/Dataset_BUSI_with_GT/*/*', size)

# %%
fig, ax = plt.subplots(1,3, figsize=(10,5))

# X[0:437] benign
# X[437:647] malignant
# X[647:780] normal

i = np.random.randint(647,780)
ax[0].imshow(X[i], cmap='gray')
ax[0].set_title('Image')
ax[1].imshow(y[i], cmap='gray')
ax[1].set_title('Mask')
ax[2].imshow(X[i], cmap='gray')
ax[2].imshow(tf.squeeze(y[i]), alpha=0.5, cmap='jet')
ax[2].set_title('Union')
fig.suptitle('Normal class', fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(10,5))

i = np.random.randint(437)
ax[0].imshow(X[i], cmap='gray')
ax[0].set_title('Image')
ax[1].imshow(y[i], cmap='gray')
ax[1].set_title('Mask')
ax[2].imshow(X[i], cmap='gray')
ax[2].imshow(tf.squeeze(y[i]), alpha=0.5, cmap='jet')
ax[2].set_title('Union')
fig.suptitle('Benign class', fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(10,5))

i = np.random.randint(437,647)
ax[0].imshow(X[i], cmap='gray')
ax[0].set_title('Image')
ax[1].imshow(y[i], cmap='gray')
ax[1].set_title('Mask')
ax[2].imshow(X[i], cmap='gray')
ax[2].imshow(tf.squeeze(y[i]), alpha=0.5, cmap='jet')
ax[2].set_title('Union')
fig.suptitle('Malignant class', fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(10,5))

ax[0].imshow(sum(y[647:]), cmap='gray')
ax[0].set_title('Normal')
ax[1].imshow(sum(y[:437]), cmap='gray')
ax[1].set_title('Benign')
ax[2].imshow(sum(y[437:647]), cmap='gray')
ax[2].set_title('Malignant')
plt.show()

# %%
# drop normal class because normal class has not mask
X = X[:647]
y = y[:647]

print(f"X shape: {X.shape}     |  y shape: {y.shape}")

# prepare data to modeling
X = np.expand_dims(X, -1)
y = np.expand_dims(y, -1)

print(f"\nX shape: {X.shape}  |  y shape: {y.shape}")
# Out:
# X shape: (647, 128, 128)     |  y shape: (647, 128, 128)
#
# X shape: (647, 128, 128, 1)  |  y shape: (647, 128, 128, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

print(f'\033[92m')
print('X_train shape:',X_train.shape)
print('y_train shape:',y_train.shape)
print('X_test shape:',X_test.shape)
print('y_test shape:',y_test.shape)
# Out:
# X_train shape: (582, 128, 128, 1)
# y_train shape: (582, 128, 128, 1)
# X_test shape: (65, 128, 128, 1)
# y_test shape: (65, 128, 128, 1)

# %%
def conv_block(input, num_filters):
    conv = Conv2D(num_filters, (3, 3), activation="relu", padding="same", kernel_initializer='he_normal')(input)
    conv = Conv2D(num_filters, (3, 3), activation="relu", padding="same", kernel_initializer='he_normal')(conv)
    return conv

# %%
def encoder_block(input, num_filters):
    conv = conv_block(input, num_filters)
    pool = MaxPooling2D((2, 2))(conv)
    return conv, pool

# %%
def decoder_block(input, skip_features, num_filters):
    uconv = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    con = concatenate([uconv, skip_features])
    conv = conv_block(con, num_filters)
    return conv

# %%
def build_model(input_shape):
    input_layer = Input(input_shape)
    
    s1, p1 = encoder_block(input_layer, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    
    output_layer = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    
    model = Model(input_layer, output_layer, name="U-Net")
    return model

model = build_model(input_shape=(size, size, 1))
model.compile(loss="binary_crossentropy", optimizer="Adam", metrics=["accuracy"])

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (0.20.3)

# %%
import pydot
print(plot_model(model, show_shapes=True))
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.
# None

# %%
import pydot
plot_model(model, show_shapes=True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
model.summary()
# Out:
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 128, 128, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 128, 128, 64)      │             640 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 128, 128, 64)      │          36,928 │ conv2d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 64, 64)        │               0 │ conv2d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 64, 64, 128)       │          73,856 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 64, 64, 128)       │         147,584 │ conv2d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 32, 128)       │               0 │ conv2d_3[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 32, 32, 256)       │         295,168 │ max_pooling2d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 32, 32, 256)       │         590,080 │ conv2d_4[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 16, 256)       │               0 │ conv2d_5[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_6 (Conv2D)             │ (None, 16, 16, 512)       │       1,180,160 │ max_pooling2d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_7 (Conv2D)             │ (None, 16, 16, 512)       │       2,359,808 │ conv2d_6[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 8, 8, 512)         │               0 │ conv2d_7[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_8 (Conv2D)             │ (None, 8, 8, 1024)        │       4,719,616 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_9 (Conv2D)             │ (None, 8, 8, 1024)        │       9,438,208 │ conv2d_8[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose              │ (None, 16, 16, 512)       │       2,097,664 │ conv2d_9[0][0]             │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 16, 16, 1024)      │               0 │ conv2d_transpose[0][0],    │
# │                               │                           │                 │ conv2d_7[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_10 (Conv2D)            │ (None, 16, 16, 512)       │       4,719,104 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_11 (Conv2D)            │ (None, 16, 16, 512)       │       2,359,808 │ conv2d_10[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_1            │ (None, 32, 32, 256)       │         524,544 │ conv2d_11[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 32, 32, 512)       │               0 │ conv2d_transpose_1[0][0],  │
# │                               │                           │                 │ conv2d_5[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_12 (Conv2D)            │ (None, 32, 32, 256)       │       1,179,904 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_13 (Conv2D)            │ (None, 32, 32, 256)       │         590,080 │ conv2d_12[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_2            │ (None, 64, 64, 128)       │         131,200 │ conv2d_13[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 64, 64, 256)       │               0 │ conv2d_transpose_2[0][0],  │
# │                               │                           │                 │ conv2d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_14 (Conv2D)            │ (None, 64, 64, 128)       │         295,040 │ concatenate_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_15 (Conv2D)            │ (None, 64, 64, 128)       │         147,584 │ conv2d_14[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_3            │ (None, 128, 128, 64)      │          32,832 │ conv2d_15[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_3 (Concatenate)   │ (None, 128, 128, 128)     │               0 │ conv2d_transpose_3[0][0],  │
# │                               │                           │                 │ conv2d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_16 (Conv2D)            │ (None, 128, 128, 64)      │          73,792 │ concatenate_3[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_17 (Conv2D)            │ (None, 128, 128, 64)      │          36,928 │ conv2d_16[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 128, 128, 1)       │              65 │ conv2d_17[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 31,030,593 (118.37 MB)
#  Trainable params: 31,030,593 (118.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs = 100, validation_data = (X_test,y_test))
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 371s 19s/step - accuracy: 0.8006 - loss: 0.4237 - val_accuracy: 0.8949 - val_loss: 0.3572
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 260s 12s/step - accuracy: 0.9087 - loss: 0.3186 - val_accuracy: 0.8949 - val_loss: 0.2822
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 229s 12s/step - accuracy: 0.9006 - loss: 0.2810 - val_accuracy: 0.8966 - val_loss: 0.2670
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 255s 13s/step - accuracy: 0.9098 - loss: 0.2371 - val_accuracy: 0.9032 - val_loss: 0.2636
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 281s 15s/step - accuracy: 0.9014 - loss: 0.2661 - val_accuracy: 0.8957 - val_loss: 0.2846
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 325s 17s/step - accuracy: 0.9053 - loss: 0.2429 - val_accuracy: 0.8990 - val_loss: 0.2400
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 372s 17s/step - accuracy: 0.9082 - loss: 0.2291 - val_accuracy: 0.9095 - val_loss: 0.2976
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 338s 18s/step - accuracy: 0.9014 - loss: 0.2780 - val_accuracy: 0.8962 - val_loss: 0.2794
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 336s 18s/step - accuracy: 0.9013 - loss: 0.2397 - val_accuracy: 0.9000 - val_loss: 0.2486
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 336s 18s/step - accuracy: 0.9158 - loss: 0.2053 - val_accuracy: 0.9086 - val_loss: 0.2634
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 339s 18s/step - accuracy: 0.9165 - loss: 0.2190 - val_accuracy: 0.9148 - val_loss: 0.2225
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 347s 18s/step - accuracy: 0.9289 - loss: 0.1863 - val_accuracy: 0.9148 - val_loss: 0.2128
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 340s 18s/step - accuracy: 0.9299 - loss: 0.2063 - val_accuracy: 0.9151 - val_loss: 0.2058
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 338s 18s/step - accuracy: 0.9256 - loss: 0.1866 - val_accuracy: 0.9201 - val_loss: 0.2030
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 346s 18s/step - accuracy: 0.9310 - loss: 0.1738 - val_accuracy: 0.9192 - val_loss: 0.2135
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 355s 19s/step - accuracy: 0.9377 - loss: 0.1581 - val_accuracy: 0.9242 - val_loss: 0.1894
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 337s 18s/step - accuracy: 0.9373 - loss: 0.1626 - val_accuracy: 0.9232 - val_loss: 0.2037
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 377s 18s/step - accuracy: 0.9366 - loss: 0.1733 - val_accuracy: 0.9164 - val_loss: 0.2137
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 336s 18s/step - accuracy: 0.9456 - loss: 0.1448 - val_accuracy: 0.9250 - val_loss: 0.1887
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 339s 18s/step - accuracy: 0.9486 - loss: 0.1319 - val_accuracy: 0.9147 - val_loss: 0.2031
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 344s 18s/step - accuracy: 0.9517 - loss: 0.1263 - val_accuracy: 0.9266 - val_loss: 0.1882
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 370s 18s/step - accuracy: 0.9528 - loss: 0.1181 - val_accuracy: 0.9305 - val_loss: 0.1790
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 360s 19s/step - accuracy: 0.9516 - loss: 0.1230 - val_accuracy: 0.9203 - val_loss: 0.2181
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 342s 18s/step - accuracy: 0.9454 - loss: 0.1408 - val_accuracy: 0.9250 - val_loss: 0.1884
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 344s 18s/step - accuracy: 0.9564 - loss: 0.1123 - val_accuracy: 0.9289 - val_loss: 0.1974
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 365s 17s/step - accuracy: 0.9569 - loss: 0.1032 - val_accuracy: 0.9091 - val_loss: 0.2371
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 339s 18s/step - accuracy: 0.9577 - loss: 0.1037 - val_accuracy: 0.9276 - val_loss: 0.2643
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 377s 18s/step - accuracy: 0.9642 - loss: 0.0870 - val_accuracy: 0.9327 - val_loss: 0.2005
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 344s 18s/step - accuracy: 0.9664 - loss: 0.0821 - val_accuracy: 0.9240 - val_loss: 0.2368
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 345s 18s/step - accuracy: 0.9669 - loss: 0.0836 - val_accuracy: 0.9286 - val_loss: 0.1972
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 347s 18s/step - accuracy: 0.9679 - loss: 0.0783 - val_accuracy: 0.9363 - val_loss: 0.2042
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 337s 18s/step - accuracy: 0.9721 - loss: 0.0687 - val_accuracy: 0.9325 - val_loss: 0.2016
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 341s 18s/step - accuracy: 0.9754 - loss: 0.0600 - val_accuracy: 0.9342 - val_loss: 0.1928
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 348s 18s/step - accuracy: 0.9763 - loss: 0.0574 - val_accuracy: 0.9344 - val_loss: 0.2340
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 348s 18s/step - accuracy: 0.9770 - loss: 0.0535 - val_accuracy: 0.9422 - val_loss: 0.2110
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 336s 18s/step - accuracy: 0.9783 - loss: 0.0496 - val_accuracy: 0.9366 - val_loss: 0.1908
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 365s 17s/step - accuracy: 0.9805 - loss: 0.0453 - val_accuracy: 0.9333 - val_loss: 0.2063
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 332s 17s/step - accuracy: 0.9774 - loss: 0.0529 - val_accuracy: 0.9337 - val_loss: 0.2690
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 340s 18s/step - accuracy: 0.9801 - loss: 0.0449 - val_accuracy: 0.9382 - val_loss: 0.2533
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 334s 18s/step - accuracy: 0.9810 - loss: 0.0431 - val_accuracy: 0.9378 - val_loss: 0.2564
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 335s 18s/step - accuracy: 0.9829 - loss: 0.0378 - val_accuracy: 0.9415 - val_loss: 0.2472
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 340s 18s/step - accuracy: 0.9836 - loss: 0.0370 - val_accuracy: 0.9409 - val_loss: 0.2410
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 332s 17s/step - accuracy: 0.9849 - loss: 0.0326 - val_accuracy: 0.9403 - val_loss: 0.2872
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 377s 17s/step - accuracy: 0.9860 - loss: 0.0300 - val_accuracy: 0.9406 - val_loss: 0.3169
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 355s 19s/step - accuracy: 0.9867 - loss: 0.0285 - val_accuracy: 0.9362 - val_loss: 0.2783
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 400s 21s/step - accuracy: 0.9862 - loss: 0.0296 - val_accuracy: 0.9338 - val_loss: 0.2822
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 399s 21s/step - accuracy: 0.9854 - loss: 0.0325 - val_accuracy: 0.9370 - val_loss: 0.2890
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 389s 20s/step - accuracy: 0.9852 - loss: 0.0320 - val_accuracy: 0.9351 - val_loss: 0.2341
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 452s 21s/step - accuracy: 0.9856 - loss: 0.0322 - val_accuracy: 0.9375 - val_loss: 0.2816
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 391s 18s/step - accuracy: 0.9861 - loss: 0.0294 - val_accuracy: 0.9347 - val_loss: 0.3352
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 356s 19s/step - accuracy: 0.9883 - loss: 0.0245 - val_accuracy: 0.9361 - val_loss: 0.3386
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 394s 21s/step - accuracy: 0.9859 - loss: 0.0310 - val_accuracy: 0.9344 - val_loss: 0.2559
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 383s 20s/step - accuracy: 0.9831 - loss: 0.0397 - val_accuracy: 0.9350 - val_loss: 0.2197
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 335s 18s/step - accuracy: 0.9848 - loss: 0.0341 - val_accuracy: 0.9336 - val_loss: 0.2905
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 336s 18s/step - accuracy: 0.9859 - loss: 0.0314 - val_accuracy: 0.9367 - val_loss: 0.2857
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 335s 18s/step - accuracy: 0.9870 - loss: 0.0280 - val_accuracy: 0.9360 - val_loss: 0.3269
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9878 - loss: 0.0267 - val_accuracy: 0.9327 - val_loss: 0.4115
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9886 - loss: 0.0235 - val_accuracy: 0.9361 - val_loss: 0.3254
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9891 - loss: 0.0225 - val_accuracy: 0.9357 - val_loss: 0.3906
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9895 - loss: 0.0216 - val_accuracy: 0.9387 - val_loss: 0.2801
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 331s 17s/step - accuracy: 0.9891 - loss: 0.0227 - val_accuracy: 0.9387 - val_loss: 0.2674
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 333s 17s/step - accuracy: 0.9904 - loss: 0.0197 - val_accuracy: 0.9401 - val_loss: 0.3734
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9906 - loss: 0.0188 - val_accuracy: 0.9415 - val_loss: 0.3833
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9919 - loss: 0.0160 - val_accuracy: 0.9386 - val_loss: 0.4160
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9917 - loss: 0.0162 - val_accuracy: 0.9380 - val_loss: 0.4014
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9920 - loss: 0.0154 - val_accuracy: 0.9413 - val_loss: 0.4454
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9922 - loss: 0.0149 - val_accuracy: 0.9401 - val_loss: 0.4437
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 334s 18s/step - accuracy: 0.9924 - loss: 0.0145 - val_accuracy: 0.9396 - val_loss: 0.4701
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 331s 17s/step - accuracy: 0.9931 - loss: 0.0130 - val_accuracy: 0.9387 - val_loss: 0.5432
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 331s 17s/step - accuracy: 0.9929 - loss: 0.0135 - val_accuracy: 0.9390 - val_loss: 0.4686
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9928 - loss: 0.0135 - val_accuracy: 0.9386 - val_loss: 0.5133
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 331s 17s/step - accuracy: 0.9934 - loss: 0.0126 - val_accuracy: 0.9392 - val_loss: 0.5043
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 328s 17s/step - accuracy: 0.9927 - loss: 0.0141 - val_accuracy: 0.9365 - val_loss: 0.4756
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9926 - loss: 0.0150 - val_accuracy: 0.9353 - val_loss: 0.3619
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9924 - loss: 0.0153 - val_accuracy: 0.9354 - val_loss: 0.3867
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 328s 17s/step - accuracy: 0.9927 - loss: 0.0142 - val_accuracy: 0.9388 - val_loss: 0.3915
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9935 - loss: 0.0123 - val_accuracy: 0.9379 - val_loss: 0.4680
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9934 - loss: 0.0120 - val_accuracy: 0.9395 - val_loss: 0.4020
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 328s 17s/step - accuracy: 0.9909 - loss: 0.0228 - val_accuracy: 0.9366 - val_loss: 0.3174
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 334s 18s/step - accuracy: 0.9909 - loss: 0.0189 - val_accuracy: 0.9374 - val_loss: 0.3674
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 328s 17s/step - accuracy: 0.9925 - loss: 0.0144 - val_accuracy: 0.9346 - val_loss: 0.4997
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 328s 17s/step - accuracy: 0.9914 - loss: 0.0183 - val_accuracy: 0.9212 - val_loss: 0.2769
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9814 - loss: 0.0464 - val_accuracy: 0.9369 - val_loss: 0.1854
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 328s 17s/step - accuracy: 0.9830 - loss: 0.0398 - val_accuracy: 0.9299 - val_loss: 0.2422
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 328s 17s/step - accuracy: 0.9855 - loss: 0.0321 - val_accuracy: 0.9392 - val_loss: 0.2372
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9862 - loss: 0.0318 - val_accuracy: 0.9342 - val_loss: 0.2817
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9867 - loss: 0.0298 - val_accuracy: 0.9408 - val_loss: 0.3074
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9893 - loss: 0.0234 - val_accuracy: 0.9368 - val_loss: 0.3375
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9911 - loss: 0.0176 - val_accuracy: 0.9371 - val_loss: 0.3973
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 327s 17s/step - accuracy: 0.9930 - loss: 0.0135 - val_accuracy: 0.9364 - val_loss: 0.4545
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9930 - loss: 0.0138 - val_accuracy: 0.9357 - val_loss: 0.4202
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 387s 18s/step - accuracy: 0.9931 - loss: 0.0127 - val_accuracy: 0.9371 - val_loss: 0.4748
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9942 - loss: 0.0103 - val_accuracy: 0.9354 - val_loss: 0.4600
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 331s 17s/step - accuracy: 0.9941 - loss: 0.0106 - val_accuracy: 0.9370 - val_loss: 0.5421
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9948 - loss: 0.0091 - val_accuracy: 0.9371 - val_loss: 0.5426
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 329s 17s/step - accuracy: 0.9949 - loss: 0.0086 - val_accuracy: 0.9374 - val_loss: 0.5492
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9949 - loss: 0.0087 - val_accuracy: 0.9360 - val_loss: 0.5538
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9947 - loss: 0.0094 - val_accuracy: 0.9345 - val_loss: 0.5289
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 331s 17s/step - accuracy: 0.9904 - loss: 0.0216 - val_accuracy: 0.9353 - val_loss: 0.3284
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 330s 17s/step - accuracy: 0.9889 - loss: 0.0262 - val_accuracy: 0.9371 - val_loss: 0.3043

# %%
fig, ax = plt.subplots(5,3, figsize=(10,18))

j = np.random.randint(0, X_test.shape[0], 5)
for i in range(5):
    ax[i,0].imshow(X_test[j[i]], cmap='gray')
    ax[i,0].set_title('Image')
    ax[i,1].imshow(y_test[j[i]], cmap='gray')
    ax[i,1].set_title('Mask')
    ax[i,2].imshow(model.predict(np.expand_dims(X_test[j[i]],0),verbose=0)[0], cmap='gray')
    ax[i,2].set_title('Prediction')
fig.suptitle('Results', fontsize=16)
plt.show()

# %%
print(f'\033[93m')
y_pred=model.predict(X_test,verbose=0)
y_pred_thresholded = y_pred > 0.5

# mean Intersection-Over-Union metric
IOU_keras = MeanIoU(num_classes=2)
IOU_keras.update_state(y_pred_thresholded, y_test)
print("Mean IoU =", IOU_keras.result().numpy())

prec_score = Precision()
prec_score.update_state(y_pred_thresholded, y_test)
p = prec_score.result().numpy()
print('Precision Score = %.3f' % p)

recall_score = Recall()
recall_score.update_state(y_pred_thresholded, y_test)
r = recall_score.result().numpy()
print('Recall Score = %.3f' % r)

f1_score = 2*(p*r)/(p+r)
print('F1 Score = %.3f' % f1_score)
# Out:
# Mean IoU = 0.72948146
# Precision Score = 0.655
# Recall Score = 0.726
# F1 Score = 0.688
